# %%
from torch import Tensor, nn, optim
import numpy as np

# %%
import random
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
np.random.seed(1337)
random.seed(1337)

# %%
# make up a dataset
from sklearn.datasets import make_moons
X, y = make_moons(n_samples=100, noise=0.1)

# visualize in 2D
plt.figure(figsize=(5,5))
plt.scatter(X[:,0], X[:,1], c=y, s=20, cmap='jet')

# %%
model = nn.Sequential(
    nn.Linear(2, 16), nn.ReLU(),
    nn.Linear(16, 16), nn.ReLU(),
    nn.Linear(16, 1), nn.Sigmoid(),
)

# %%
# loss function
def loss():
    Xb, yb = Tensor(X), Tensor(y)

    # forward the model to get scores
    scores = model(Xb)
    scores = scores.flatten(0)

    # binary crossentropy loss
    data_loss = -((yb * scores.log()) + (1 - yb) * (1 - scores).log()).mean()

    # L2 regularization
    reg_loss = 0
    for params in model.parameters():
        reg_loss += params.pow(2).sum()
    reg_loss *= 1e-4 # alpha=1e-4
    total_loss = data_loss + reg_loss

    # also get accuracy
    accuracy = [(yi > 0.5) == (scorei > 0.5) for yi, scorei in zip(yb.data, scores.data)]
    return total_loss, sum(accuracy) / len(accuracy)

total_loss, acc = loss()
print(total_loss, acc)
# Out:
# tensor(0.6824, grad_fn=<AddBackward0>) tensor(0.7700)

# %%
# optimization
optimizer = optim.SGD(model.parameters(), lr=0.1)

for k in range(1500):
    # forward
    total_loss, acc = loss()

    # backward
    optimizer.zero_grad()
    total_loss.backward()

    # update
    optimizer.step()

    if k % 100 == 0:
        print(f"step {k} loss {total_loss.item():.4f} accuracy {acc*100:.1f}%")
# Out:
# step 0 loss 0.6824 accuracy 77.0%
# step 100 loss 0.3546 accuracy 85.0%
# step 200 loss 0.2771 accuracy 88.0%
# step 300 loss 0.2568 accuracy 91.0%
# step 400 loss 0.2406 accuracy 91.0%
# step 500 loss 0.2248 accuracy 89.0%
# step 600 loss 0.2043 accuracy 92.0%
# step 700 loss 0.1729 accuracy 92.0%
# step 800 loss 0.1243 accuracy 95.0%
# step 900 loss 0.0662 accuracy 99.0%
# step 1000 loss 0.0436 accuracy 100.0%
# step 1100 loss 0.0315 accuracy 100.0%
# step 1200 loss 0.0245 accuracy 100.0%
# step 1300 loss 0.0204 accuracy 100.0%
# step 1400 loss 0.0178 accuracy 100.0%

# %%
# visualize decision boundary

h = 0.25
x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
Xmesh = np.c_[xx.ravel(), yy.ravel()]
inputs = Tensor(Xmesh)
scores = model(inputs)
Z = np.array([scores.data > 0.5])
Z = Z.reshape(xx.shape)

fig = plt.figure()
plt.contourf(xx, yy, Z, cmap=plt.cm.Spectral, alpha=0.8)
plt.scatter(X[:, 0], X[:, 1], c=y, s=40, cmap=plt.cm.Spectral)
plt.xlim(xx.min(), xx.max())
plt.ylim(yy.min(), yy.max())
# Out:
# (-1.548639298268643, 1.951360701731357)
